# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %% [markdown]
# ### Doc2vec & RF

# %%
features_train = pickle.load(open('../doc2vec_results_1/features_train_doc2vec.pkl', 'rb'))
model = pickle.load(open('../doc2vec_results_1/model_doc2vec_RF.pkl', 'rb'))
predictions = model.predict(features_train)

# %%
n, bins, patches = plt.hist(predictions, 10)
plt.xlabel('Prediction')
plt.ylabel('Number of predictions')
plt.title('Distribution of preditions for Doc2vec and RF')
# plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ### WMD & RF

# %%
features_train = pickle.load(open('../wmd_rf_results/features_train_wmd.pkl', 'rb'))
model = pickle.load(open('../wmd_rf_results/model_wmd_RF.pkl', 'rb'))
predictions = model.predict(features_train)

# %%
n, bins, patches = plt.hist(predictions, 10)
plt.xlabel('Prediction')
plt.ylabel('Number of predictions')
plt.title('Distribution of preditions for WMD and RF')
# plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Word2vec & RF

# %%
features_train = pickle.load(open('../word2vec_results/features_train_word2vec.pkl', 'rb'))
model = pickle.load(open('../word2vec_results/model_word2vec_RF.pkl', 'rb'))
predictions = model.predict(features_train)

# %%
n, bins, patches = plt.hist(predictions, 10)
plt.xlabel('Prediction')
plt.ylabel('Number of predictions')
plt.title('Distribution of preditions for Word2vec and RF')
# plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
